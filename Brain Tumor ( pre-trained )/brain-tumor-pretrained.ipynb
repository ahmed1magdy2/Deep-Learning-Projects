# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
import cv2
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.layers import Dense, Flatten, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adam
from keras.models import Sequential, load_model
from keras.optimizers import Adam

# %%
imageGen = ImageDataGenerator(ImageDataGenerator(
        rescale= 1./255.,
        shear_range=0.1,
        zoom_range=0.1,
        rotation_range=30,
        horizontal_flip=True,
        brightness_range=(0.5, 1.0)))

# %%
train_set = imageGen.flow_from_directory('/kaggle/input/brain-tumor-mri-dataset/Training',
                                                 target_size = (224,224),
                                                 color_mode = "rgb",
                                                 batch_size=16,
                                                 class_mode = 'binary',
                                                 classes={'glioma': 0., 'meningioma': 1.,'notumor':2,'pituitary':3})
test_set = imageGen.flow_from_directory('/kaggle/input/brain-tumor-mri-dataset/Testing',
                                                 target_size = (224,224),
                                                 color_mode = "rgb",
                                                 batch_size=16,
                                                 class_mode = 'binary',
                                                 classes={'glioma': 0., 'meningioma': 1.,'notumor':2,'pituitary':3})

# %%
train_set.class_indices

# %%
#path_of_model = '/kaggle/input/bt-model-weights/model_brain_tumor.h5'
path_of_model = '/kaggle/input/resnet50-model-weights/resnet50_weights_tf_dim_ordering_tf_kernels.h5'

# %%
base_model = ResNet50(weights=None)

# %%
base_model = load_model(path_of_model)

# %%
base_model.trainable = False
model1 = Sequential([
    base_model, 
    Flatten(),
    Dense(256, activation="relu", kernel_initializer='he_normal'),
    Dropout(0.3),
    Dense(4, activation='softmax')
])

# %%
model1.compile(optimizer=
              Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 4)                 25893996
#
#  flatten (Flatten)           (None, 4)                 0
#
#  dense (Dense)               (None, 256)               1280
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 25,896,304
# Trainable params: 2,308
# Non-trainable params: 25,893,996
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('model_brain_tumor.h5', 
                                                monitor='accuracy', verbose=1, 
                                                mode='max',save_best_only=True)
early = tf.keras.callbacks.EarlyStopping(monitor="accuracy",
                                         mode="max",
                                         restore_best_weights=True,
                                         patience=10)
callbacks_list = [checkpoint,early]

history = model1.fit(train_set,
                     validation_data=test_set,
                     epochs=200,
                     callbacks=callbacks_list)
# Out:
# Epoch 1/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8810
# Epoch 1: accuracy improved from -inf to 0.88095, saving model to model_brain_tumor.h5
# 357/357 [==============================] - 623s 2s/step - loss: 0.3714 - accuracy: 0.8810 - val_loss: 0.3498 - val_accuracy: 0.8818
# Epoch 2/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8817
# Epoch 2: accuracy improved from 0.88095 to 0.88165, saving model to model_brain_tumor.h5
# 357/357 [==============================] - 579s 2s/step - loss: 0.3583 - accuracy: 0.8817 - val_loss: 0.3439 - val_accuracy: 0.8833
# Epoch 3/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8836
# Epoch 3: accuracy improved from 0.88165 to 0.88358, saving model to model_brain_tumor.h5
# 357/357 [==============================] - 592s 2s/step - loss: 0.3537 - accuracy: 0.8836 - val_loss: 0.3496 - val_accuracy: 0.8802
# Epoch 4/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3618 - accuracy: 0.8759
# Epoch 4: accuracy did not improve from 0.88358
# 357/357 [==============================] - 585s 2s/step - loss: 0.3618 - accuracy: 0.8759 - val_loss: 0.3441 - val_accuracy: 0.8802
# Epoch 5/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3490 - accuracy: 0.8834
# Epoch 5: accuracy did not improve from 0.88358
# 357/357 [==============================] - 590s 2s/step - loss: 0.3490 - accuracy: 0.8834 - val_loss: 0.3418 - val_accuracy: 0.8833
# Epoch 6/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.8808
# Epoch 6: accuracy did not improve from 0.88358
# 357/357 [==============================] - 582s 2s/step - loss: 0.3521 - accuracy: 0.8808 - val_loss: 0.3414 - val_accuracy: 0.8802
# Epoch 7/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3512 - accuracy: 0.8818
# Epoch 7: accuracy did not improve from 0.88358
# 357/357 [==============================] - 580s 2s/step - loss: 0.3512 - accuracy: 0.8818 - val_loss: 0.3406 - val_accuracy: 0.8841
# Epoch 8/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3390 - accuracy: 0.8801
# Epoch 8: accuracy did not improve from 0.88358
# 357/357 [==============================] - 584s 2s/step - loss: 0.3390 - accuracy: 0.8801 - val_loss: 0.3414 - val_accuracy: 0.8818
# Epoch 9/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3482 - accuracy: 0.8818
# Epoch 9: accuracy did not improve from 0.88358
# 357/357 [==============================] - 584s 2s/step - loss: 0.3482 - accuracy: 0.8818 - val_loss: 0.3391 - val_accuracy: 0.8810
# Epoch 10/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3481 - accuracy: 0.8810
# Epoch 10: accuracy did not improve from 0.88358
# 357/357 [==============================] - 584s 2s/step - loss: 0.3481 - accuracy: 0.8810 - val_loss: 0.3378 - val_accuracy: 0.8810
# Epoch 11/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3429 - accuracy: 0.8825
# Epoch 11: accuracy did not improve from 0.88358
# 357/357 [==============================] - 616s 2s/step - loss: 0.3429 - accuracy: 0.8825 - val_loss: 0.3403 - val_accuracy: 0.8810
# Epoch 12/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3440 - accuracy: 0.8848
# Epoch 12: accuracy improved from 0.88358 to 0.88480, saving model to model_brain_tumor.h5
# 357/357 [==============================] - 584s 2s/step - loss: 0.3440 - accuracy: 0.8848 - val_loss: 0.3389 - val_accuracy: 0.8818
# Epoch 13/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8820
# Epoch 13: accuracy did not improve from 0.88480
# 357/357 [==============================] - 580s 2s/step - loss: 0.3446 - accuracy: 0.8820 - val_loss: 0.3357 - val_accuracy: 0.8833
# Epoch 14/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3467 - accuracy: 0.8804
# Epoch 14: accuracy did not improve from 0.88480
# 357/357 [==============================] - 587s 2s/step - loss: 0.3467 - accuracy: 0.8804 - val_loss: 0.3365 - val_accuracy: 0.8802
# Epoch 15/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3415 - accuracy: 0.8878
# Epoch 15: accuracy improved from 0.88480 to 0.88778, saving model to model_brain_tumor.h5
# 357/357 [==============================] - 583s 2s/step - loss: 0.3415 - accuracy: 0.8878 - val_loss: 0.3396 - val_accuracy: 0.8810
# Epoch 16/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.8810
# Epoch 16: accuracy did not improve from 0.88778
# 357/357 [==============================] - 588s 2s/step - loss: 0.3468 - accuracy: 0.8810 - val_loss: 0.3420 - val_accuracy: 0.8802
# Epoch 17/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3469 - accuracy: 0.8806
# Epoch 17: accuracy did not improve from 0.88778
# 357/357 [==============================] - 586s 2s/step - loss: 0.3469 - accuracy: 0.8806 - val_loss: 0.3360 - val_accuracy: 0.8802
# Epoch 18/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8818
# Epoch 18: accuracy did not improve from 0.88778
# 357/357 [==============================] - 584s 2s/step - loss: 0.3433 - accuracy: 0.8818 - val_loss: 0.3356 - val_accuracy: 0.8856
# Epoch 19/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3378 - accuracy: 0.8843
# Epoch 19: accuracy did not improve from 0.88778
# 357/357 [==============================] - 588s 2s/step - loss: 0.3378 - accuracy: 0.8843 - val_loss: 0.3368 - val_accuracy: 0.8848
# Epoch 20/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3376 - accuracy: 0.8850
# Epoch 20: accuracy did not improve from 0.88778
# 357/357 [==============================] - 588s 2s/step - loss: 0.3376 - accuracy: 0.8850 - val_loss: 0.3378 - val_accuracy: 0.8841
# Epoch 21/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3352 - accuracy: 0.8852
# Epoch 21: accuracy did not improve from 0.88778
# 357/357 [==============================] - 585s 2s/step - loss: 0.3352 - accuracy: 0.8852 - val_loss: 0.3475 - val_accuracy: 0.8787
# Epoch 22/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3448 - accuracy: 0.8820
# Epoch 22: accuracy did not improve from 0.88778
# 357/357 [==============================] - 588s 2s/step - loss: 0.3448 - accuracy: 0.8820 - val_loss: 0.3350 - val_accuracy: 0.8863
# Epoch 23/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8803
# Epoch 23: accuracy did not improve from 0.88778
# 357/357 [==============================] - 592s 2s/step - loss: 0.3433 - accuracy: 0.8803 - val_loss: 0.3370 - val_accuracy: 0.8810
# Epoch 24/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.8839
# Epoch 24: accuracy did not improve from 0.88778
# 357/357 [==============================] - 590s 2s/step - loss: 0.3372 - accuracy: 0.8839 - val_loss: 0.3361 - val_accuracy: 0.8810
# Epoch 25/200
# 357/357 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.8825
# Epoch 25: accuracy did not improve from 0.88778
# 357/357 [==============================] - 638s 2s/step - loss: 0.3388 - accuracy: 0.8825 - val_loss: 0.3357 - val_accuracy: 0.8810

# %%
model1.evaluate(train_set)
# Out:
# 357/357 [==============================] - 494s 1s/step - loss: 0.3004 - accuracy: 0.8936
# [0.3004097640514374, 0.8935574293136597]

# %%
model1.evaluate(test_set)
# Out:
# 82/82 [==============================] - 113s 1s/step - loss: 0.3396 - accuracy: 0.8810
# [0.3396451771259308, 0.8810068368911743]

# %%
from tensorflow.keras.preprocessing import image

# %%
labels = [i: i in train_set.class_indices]

# %%
def predict_image(path):
    img = image.load_img(path,target_size=(224,224))
    img = np.expand_dims(img, axis=0)
    p = model1.predict(img)
    pred = [np.argmax(element) for element in p]
    print (plt.imshow(cv2.imread(path)))
    return labels[pred[0]]

# %%
predict_image('/kaggle/input/brain-tumor-classification-mri/Testing/glioma_tumor/image(10).jpg')
